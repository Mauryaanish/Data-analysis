# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data = pd.read_csv("adult.data")

# %%
data
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %% [markdown]
# # Data cleaning

# %%
data_copy.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data_copy = pd.read_csv("adult.data" , header=None , names = ["Age" , "Work-Class" , "Final Weight" , "Education" , "Education-Num" , "Marital Status" , "Occupation" , "Relationship" , "Race" , "Sex" , "Captital Gain" , "Capital Loss" , "Hour-Per-Week" , "Netive Country" , "NaN"])

# %%
data_copy
# Out:
#        Age         Work-Class  Final Weight    Education  Education-Num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
data_copy["Age"].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
data_copy["Age"].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: Age, Length: 32561, dtype: bool

# %%
data_copy["Age"].dtype
# Out:
# dtype('int64')

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country     NaN
# 0           2174             0             40   United-States   <=50K
# 1              0             0             13   United-States   <=50K

# %%
data_copy["Work-Class"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data_copy["Work-Class"].mode()
# Out:
# 0     Private
# Name: Work-Class, dtype: object

# %%
data_copy["Work-Class"] = data_copy["Work-Class"].str.replace("?" , "Private")

# %%
data_copy["Work-Class"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
data_copy["Work-Class"].dtype
# Out:
# dtype('O')

# %%
data_copy["Work-Class"] = data_copy["Work-Class"].str.replace("-" , " ")

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never married      Adm-clerical   Not-in-family   White   Male
# 1   Married civ spouse   Exec-managerial         Husband   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0           2174             0             40   United-States
# 1              0             0             13   United-States

# %%
data_copy["Final Weight"].unique()
# Out:
# array([ 77516,  83311, 215646, ...,  34066,  84661, 257302], dtype=int64)

# %%
data_copy[["Final Weight"]]
# Out:
#        Final Weight
# 0             77516
# 1             83311
# 2            215646
# 3            234721
# 4            338409
# ...             ...
# 32556        257302
# 32557        154374
# 32558        151910
# 32559        201490
# 32560        287927
#
# [32561 rows x 1 columns]

# %%
data_copy =data_copy.drop("NaN" , axis =1)

# %%
data_copy
# Out:
#        Age         Work-Class  Final Weight    Education  Education-Num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
data_copy["Education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data_copy.columns
# Out:
# Index(['Age', 'Work-Class', 'Final Weight', 'Education', 'Education-Num',
#        'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Captital Gain', 'Capital Loss', 'Hour-Per-Week', 'Netive Country'],
#       dtype='object')

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Work-Class      32561 non-null  object
#  2   Final Weight    32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education-Num   32561 non-null  int64
#  5   Marital Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Sex             32561 non-null  object
#  10  Captital Gain   32561 non-null  int64
#  11  Capital Loss    32561 non-null  int64
#  12  Hour-Per-Week   32561 non-null  int64
#  13  Netive Country  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
data_copy[data_copy["Sex"].str.strip() == "Male"]
# Out:
#        Age         Work-Class  Final Weight      Education  Education-Num  \
# 0       39          State-gov         77516      Bachelors             13
# 1       50   Self-emp-not-inc         83311      Bachelors             13
# 2       38            Private        215646        HS-grad              9
# 3       53            Private        234721           11th              7
# 7       52   Self-emp-not-inc        209642        HS-grad              9
# ...    ...                ...           ...            ...            ...
# 32553   32            Private        116138        Masters             14
# 32554   53            Private        321865        Masters             14
# 32555   22            Private        310152   Some-college             10
# 32557   40            Private        154374        HS-grad              9
# 32559   22            Private        201490        HS-grad              9
#
#             Marital Status          Occupation    Relationship  \
# ...

# %%
data_copy["Sex"].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0           2174             0             40   United-States
# 1              0             0             13   United-States

# %%
data_copy["Education-Num"].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
data_copy["Education-Num"].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: Education-Num, Length: 32561, dtype: bool

# %%
data_copy["Marital Status"].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data_copy["Marital Status"] = data_copy["Marital Status"].str.replace("-" , " ")

# %%
data_copy["Marital Status"]
# Out:
# 0              Never married
# 1         Married civ spouse
# 2                   Divorced
# 3         Married civ spouse
# 4         Married civ spouse
#                 ...
# 32556     Married civ spouse
# 32557     Married civ spouse
# 32558                Widowed
# 32559          Never married
# 32560     Married civ spouse
# Name: Marital Status, Length: 32561, dtype: object

# %%
data_copy["Marital Status"] = data_copy["Marital Status"].str.replace("m" , "M")

# %%
data_copy["Marital Status"] = data_copy["Marital Status"].str.replace("s" , "S")

# %%
data_copy["Marital Status"]
# Out:
# 0              Never Married
# 1         Married civ SpouSe
# 2                   Divorced
# 3         Married civ SpouSe
# 4         Married civ SpouSe
#                 ...
# 32556     Married civ SpouSe
# 32557     Married civ SpouSe
# 32558                Widowed
# 32559          Never Married
# 32560     Married civ SpouSe
# Name: Marital Status, Length: 32561, dtype: object

# %%
data_copy.head(3)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
#
#         Marital Status          Occupation    Relationship    Race    Sex  \
# 0        Never Married        Adm-clerical   Not-in-family   White   Male
# 1   Married civ SpouSe     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0           2174             0             40   United-States
# 1              0             0             13   United-States
# 2              0             0             40   United-States

# %%
data_copy["Occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
value = data_copy["Occupation"].mode()

# %%
value
# Out:
# 0     Prof-specialty
# Name: Occupation, dtype: object

# %%
data_copy["Occupation"] = data_copy["Occupation"].str.replace("?" , "Prof-specialty")

# %%
data_copy["Occupation"] = data_copy["Occupation"].str.replace("-" , " ")

# %%
data_copy["Occupation"].unique()
# Out:
# array([' Adm clerical', ' Exec managerial', ' Handlers cleaners',
#        ' Prof specialty', ' Other service', ' Sales', ' Craft repair',
#        ' Transport moving', ' Farming fishing', ' Machine op inspct',
#        ' Tech support', ' Protective serv', ' Armed Forces',
#        ' Priv house serv'], dtype=object)

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never Married      Adm clerical   Not-in-family   White   Male
# 1   Married civ SpouSe   Exec managerial         Husband   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0           2174             0             40   United-States
# 1              0             0             13   United-States

# %%
data_copy["Relationship"].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
data_copy["Relationship"]= data_copy["Relationship"].str.replace("-" , " ")

# %%
data_copy["Relationship"]
# Out:
# 0         Not in family
# 1               Husband
# 2         Not in family
# 3               Husband
# 4                  Wife
#               ...
# 32556              Wife
# 32557           Husband
# 32558         Unmarried
# 32559         Own child
# 32560              Wife
# Name: Relationship, Length: 32561, dtype: object

# %%
data_copy["Race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data_copy["Race"] = data_copy["Race"].str.replace("-" , " ")

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never Married      Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe   Exec managerial         Husband   White   Male
#
#    Captital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0           2174             0             40   United-States
# 1              0             0             13   United-States

# %%
data_copy.rename(columns = {"Captital Gain" : "Capital Gain"} , inplace = True)

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never Married      Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe   Exec managerial         Husband   White   Male
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0          2174             0             40   United-States
# 1             0             0             13   United-States

# %%
data_copy["Capital Gain"].unique()
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#        34095,  4064,  4386,  7298,  1409,  3674,  1055,  3464,  2050,
#         2176,   594, 20051,  6849,  4101,  1111,  8614,  3411,  2597,
#        25236,  4650,  9386,  2463,  3103, 10605,  2964,  3325,  2580,
#         3471,  4865, 99999,  6514,  1471,  2329,  2105,  2885, 25124,
#        10520,  2202,  2961, 27828,  6767,  2228,  1506, 13550,  2635,
#         5556,  4787,  3781,  3137,  3818,  3942,   914,   401,  2829,
#         2977,  4934,  2062,  2354,  5455, 15020,  1424,  3273, 22040,
#         4416,  3908, 10566,   991,  4931,  1086,  7430,  6497,   114,
#         7896,  2346,  3418,  3432,  2907,  1151,  2414,  2290, 15831,
#        41310,  4508,  2538,  3456,  6418,  1848,  3887,  5721,  9562,
#         1455,  2036,  1831, 11678,  2936,  2993,  7443,  6360,  1797,
#         1173,  4687,  6723,  2009,  6097,  2653,  1639, 18481,  7978,
#         2387,  5060], dtype=int64)

# %%
len(data_copy[data_copy["Capital Gain"] != 0])
# Out:
# 2712

# %%
data_copy["Capital Loss"].unique()
# Out:
# array([   0, 2042, 1408, 1902, 1573, 1887, 1719, 1762, 1564, 2179, 1816,
#        1980, 1977, 1876, 1340, 2206, 1741, 1485, 2339, 2415, 1380, 1721,
#        2051, 2377, 1669, 2352, 1672,  653, 2392, 1504, 2001, 1590, 1651,
#        1628, 1848, 1740, 2002, 1579, 2258, 1602,  419, 2547, 2174, 2205,
#        1726, 2444, 1138, 2238,  625,  213, 1539,  880, 1668, 1092, 1594,
#        3004, 2231, 1844,  810, 2824, 2559, 2057, 1974,  974, 2149, 1825,
#        1735, 1258, 2129, 2603, 2282,  323, 4356, 2246, 1617, 1648, 2489,
#        3770, 1755, 3683, 2267, 2080, 2457,  155, 3900, 2201, 1944, 2467,
#        2163, 2754, 2472, 1411], dtype=int64)

# %%
len(data_copy[data_copy["Capital Loss"] == 0])
# Out:
# 31042

# %%
data_copy.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never Married      Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe   Exec managerial         Husband   White   Male
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0          2174             0             40   United-States
# 1             0             0             13   United-States

# %%
data_copy["Hour-Per-Week"].unique()
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95], dtype=int64)

# %%
data_copy["Netive Country"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data_copy["Netive Country"].mode()
# Out:
# 0     United-States
# Name: Netive Country, dtype: object

# %%
data_copy["Netive Country"] = data_copy["Netive Country"].str.replace("?" , "United States")

# %%
data_copy["Netive Country"] = data_copy["Netive Country"].str.replace("-" , " ")

# %%
data_copy.head(5)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never Married        Adm clerical   Not in family   White     Male
# 1   Married civ SpouSe     Exec managerial         Husband   White     Male
# 2             Divorced   Handlers cleaners   Not in family   White     Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black     Male
# 4   Married civ SpouSe      Prof specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# ...

# %%
data_copy.to_csv("US Census Income.csv" , index = False)

# %% [markdown]
# # Stats Based Analysis

# %%
df  = pd.read_csv("US Census Income.csv")

# %%
df
# Out:
#        Age         Work-Class  Final Weight    Education  Education-Num  \
# 0       39          State gov         77516    Bachelors             13
# 1       50   Self emp not inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self emp inc        287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype == "O"]

# %%
numerical_feature
# Out:
# []

# %%
categorical_features = []
for i in df.columns:
    if df[i].dtype == "O":
        categorical_features.append(i)
print(categorical_features)
# Out:
# ['Work-Class', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Netive Country']

# %%
categorical_features
# Out:
# ['Work-Class',
#  'Education',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Netive Country']

# %%
numerical_features = []
for i in df.columns:
    if df[i].dtype != "O":
        numerical_features.append(i)
print(numerical_features)
# Out:
# ['Age', 'Final Weight', 'Education-Num', 'Capital Gain', 'Capital Loss', 'Hour-Per-Week']

# %%
df[numerical_features]
# Out:
#        Age  Final Weight  Education-Num  Capital Gain  Capital Loss  \
# 0       39         77516             13          2174             0
# 1       50         83311             13             0             0
# 2       38        215646              9             0             0
# 3       53        234721              7             0             0
# 4       28        338409             13             0             0
# ...    ...           ...            ...           ...           ...
# 32556   27        257302             12             0             0
# 32557   40        154374              9             0             0
# 32558   58        151910              9             0             0
# 32559   22        201490              9             0             0
# 32560   52        287927              9         15024             0
#
#        Hour-Per-Week
# 0                 40
# 1                 13
# 2                 40
# 3                 40
# 4                 40
# ...

# %%
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# Age            32561.0      38.581647      13.640433     17.0      28.0
# Final Weight   32561.0  189778.366512  105549.977697  12285.0  117827.0
# Education-Num  32561.0      10.080679       2.572720      1.0       9.0
# Capital Gain   32561.0    1077.648844    7385.292085      0.0       0.0
# Capital Loss   32561.0      87.303830     402.960219      0.0       0.0
# Hour-Per-Week  32561.0      40.437456      12.347429      1.0      40.0
#
#                     50%       75%        max
# Age                37.0      48.0       90.0
# Final Weight   178356.0  237051.0  1484705.0
# Education-Num      10.0      12.0       16.0
# Capital Gain        0.0       0.0    99999.0
# Capital Loss        0.0       0.0     4356.0
# Hour-Per-Week      40.0      45.0       99.0

# %%
df.head()
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never Married        Adm clerical   Not in family   White     Male
# 1   Married civ SpouSe     Exec managerial         Husband   White     Male
# 2             Divorced   Handlers cleaners   Not in family   White     Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black     Male
# 4   Married civ SpouSe      Prof specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# ...

# %%
df["Sex"].value_counts(normalize = True)
# Out:
#  Male      0.669205
#  Female    0.330795
# Name: Sex, dtype: float64

# %%
for col in categorical_features:
    print(f"{col} : {df[col].value_counts(normalize = True)}")
    print("**********************************************************")
# Out:
# Work-Class :  Private             0.753417
#  Self emp not inc    0.078038
#  Local gov           0.064279
#  State gov           0.039864
#  Self emp inc        0.034274
#  Federal gov         0.029483
#  Without pay         0.000430
#  Never worked        0.000215
# Name: Work-Class, dtype: float64
# **********************************************************
# Education :  HS-grad         0.322502
#  Some-college    0.223918
#  Bachelors       0.164461
#  Masters         0.052916
#  Assoc-voc       0.042443
#  11th            0.036086
#  Assoc-acdm      0.032769
#  10th            0.028654
#  7th-8th         0.019840
#  Prof-school     0.017690
#  9th             0.015786
#  12th            0.013298
#  Doctorate       0.012684
#  5th-6th         0.010227
#  1st-4th         0.005160
#  Preschool       0.001566
# Name: Education, dtype: float64
# **********************************************************
# Marital Status :  Married civ SpouSe       0.459937
# ...

# %% [markdown]
# # Graph Based Analysis Categorical Part

# %%
df.head(4)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
#
#         Marital Status          Occupation    Relationship    Race    Sex  \
# 0        Never Married        Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe     Exec managerial         Husband   White   Male
# 2             Divorced   Handlers cleaners   Not in family   White   Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black   Male
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0          2174             0             40   United States
# 1             0             0             13   United States
# 2             0             0             40   United States
# ...

# %%
categorical_features
# Out:
# ['Work-Class',
#  'Education',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Netive Country']

# %%
plt.figure(figsize = (10 , 10))
sns.countplot(x = df["Work-Class"])
plt.title("Work Class Count Plot Category Wise " , fontsize=20, fontweight='bold', alpha=0.8, y=1.)
plt.show()

# %%
plt.figure(figsize = (10 , 10))
sns.countplot(x = df["Education"])
plt.title("Education Count Plot for  Category Wise " , fontsize=20, fontweight='bold', alpha=0.8, y=1.)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10 , 10))
sns.countplot(x = df["Marital Status"])
plt.title("Marital Status Count Plot for  Category Wise " , fontsize=20, fontweight='bold', alpha=0.8, y=1.)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10 , 10))
sns.countplot(x = df["Occupation"])
plt.title("Occupation Count Plot for  Category Wise " , fontsize=20, fontweight='bold', alpha=0.8, y=1.)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10 , 10))
sns.countplot(x = df["Relationship"])
plt.title("Relatonship Count Plot for  Category Wise " , fontsize=20, fontweight='bold', alpha=0.8, y=1.)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10,15))
plt.suptitle("Univariate Analysis of Categorical Features", fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = ['Race', 'Sex','Netive Country' ]
for i in range(0 , len(category)):
    plt.subplot(3 , 2 ,2+i)
    sns.countplot(x = df[category[i]] , palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
df["numerical"]
# Out:
#        Age         Work-Class  Final Weight    Education  Education-Num  \
# 0       39          State gov         77516    Bachelors             13
# 1       50   Self emp not inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self emp inc        287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
df[numerical_features]
# Out:
#        Age  Final Weight  Education-Num  Capital Gain  Capital Loss  \
# 0       39         77516             13          2174             0
# 1       50         83311             13             0             0
# 2       38        215646              9             0             0
# 3       53        234721              7             0             0
# 4       28        338409             13             0             0
# ...    ...           ...            ...           ...           ...
# 32556   27        257302             12             0             0
# 32557   40        154374              9             0             0
# 32558   58        151910              9             0             0
# 32559   22        201490              9             0             0
# 32560   52        287927              9         15024             0
#
#        Hour-Per-Week
# 0                 40
# 1                 13
# 2                 40
# 3                 40
# 4                 40
# ...

# %%
sns.kdeplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Final Weight"])
# Out:
# <AxesSubplot:xlabel='Final Weight', ylabel='Density'>

# %%
plt.hist(df["Education-Num"])
# Out:
# (array([  219.,   333.,  1160.,   933.,  1608., 10501.,  8673.,  1067.,
#          7078.,   989.]),
#  array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numerical_features)):
    plt.subplot(6, 2, i+1)
    sns.kdeplot(x=df[numerical_features[i]],shade=True, color='b')
    plt.xlabel(numerical_features[i])
    plt.tight_layout()

# %%
df.head(5)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never Married        Adm clerical   Not in family   White     Male
# 1   Married civ SpouSe     Exec managerial         Husband   White     Male
# 2             Divorced   Handlers cleaners   Not in family   White     Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black     Male
# 4   Married civ SpouSe      Prof specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# ...

# %%
df["Education"].value_counts().plot.pie(y = df["Education"] , figsize=(15,15) , autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Education'>

# %%
df["Race"].value_counts().plot.pie(y = df["Race"] , figsize=(10,10) , autopct ="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Race'>

# %%
df.head(5)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never Married        Adm clerical   Not in family   White     Male
# 1   Married civ SpouSe     Exec managerial         Husband   White     Male
# 2             Divorced   Handlers cleaners   Not in family   White     Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black     Male
# 4   Married civ SpouSe      Prof specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# ...

# %%
df1 = df.groupby(["Education"])["Education-Num"].sum().sort_values(ascending=False).reset_index()

# %%
df1
# Out:
#         Education  Education-Num
# 0         HS-grad          94509
# 1    Some-college          72910
# 2       Bachelors          69615
# 3         Masters          24122
# 4       Assoc-voc          15202
# 5      Assoc-acdm          12804
# 6     Prof-school           8640
# 7            11th           8225
# 8       Doctorate           6608
# 9            10th           5598
# 10           12th           3464
# 11        7th-8th           2584
# 12            9th           2570
# 13        5th-6th            999
# 14        1st-4th            336
# 15      Preschool             51

# %%
plt.figure(figsize = (15,15))
plt.title("Number Of Certificates" , fontsize = 20)
sns.barplot(x = df["Education"] , y= df["Education-Num"])
plt.xticks(rotation = 90)
plt.show()

# %%
df.head()
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never Married        Adm clerical   Not in family   White     Male
# 1   Married civ SpouSe     Exec managerial         Husband   White     Male
# 2             Divorced   Handlers cleaners   Not in family   White     Male
# 3   Married civ SpouSe   Handlers cleaners         Husband   Black     Male
# 4   Married civ SpouSe      Prof specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# ...

# %%
df["Work-Class"].value_counts().plot.pie(y=df["Work-Class"] , figsize=(15,15) , autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Work-Class'>

# %%
df2 = df[df["Netive Country"].str.strip() == "United States"]

# %%
df2
# Out:
#        Age         Work-Class  Final Weight    Education  Education-Num  \
# 0       39          State gov         77516    Bachelors             13
# 1       50   Self emp not inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 5       37            Private        284582      Masters             14
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self emp inc        287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# ...

# %%
df3 = df2["Occupation"].value_counts().sort_values(ascending = False).reset_index()

# %%
df3.rename(columns = {"index" : "Occupation" , "Occupation" : "Count"} , inplace = True)

# %%
df3
# Out:
#             Occupation  Count
# 0       Prof specialty   5488
# 1      Exec managerial   3809
# 2         Craft repair   3754
# 3         Adm clerical   3498
# 4                Sales   3430
# 5        Other service   2860
# 6    Machine op inspct   1723
# 7     Transport moving   1516
# 8    Handlers cleaners   1209
# 9      Farming fishing    884
# 10        Tech support    866
# 11     Protective serv    611
# 12     Priv house serv     96
# 13        Armed Forces      9

# %%
plt.figure(figsize=(15,15))
plt.title("Occupation For United States Of American Citizens" , fontsize = 20 , fontweight='bold', alpha=0.8, y=1)
sns.barplot(x = "Occupation" , y="Count" , data=df3)
plt.xticks(rotation = 90)
plt.show()

# %%
df.head(2)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
#
#         Marital Status        Occupation    Relationship    Race    Sex  \
# 0        Never Married      Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe   Exec managerial         Husband   White   Male
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0          2174             0             40   United States
# 1             0             0             13   United States

# %%
df4 = df.groupby(["Education"])["Capital Gain"].sum().sort_values(ascending = False).reset_index()

# %%
df4
# Out:
#         Education  Capital Gain
# 0       Bachelors       9404984
# 1         HS-grad       6056978
# 2     Prof-school       5998704
# 3         Masters       4415297
# 4    Some-college       4366027
# 5       Doctorate       1970070
# 6       Assoc-voc        988201
# 7      Assoc-acdm        683306
# 8            10th        377468
# 9            11th        252740
# 10            9th        175834
# 11        7th-8th        151125
# 12           12th        123010
# 13        5th-6th         58615
# 14      Preschool         45818
# 15        1st-4th         21147

# %%
plt.figure(figsize = (15,15))
plt.title("Highest Capital Gain Peoples For Education Wise " , fontsize = 20 ,fontweight='bold', alpha=0.8, y=1 )
sns.barplot(x = "Education" , y = "Capital Gain" , data = df4)
plt.xticks(rotation = 90)
plt.show()

# %%
df["Sex"].value_counts().plot.pie(y=df["Sex"] , figsize=(10,10) , autopct = "1%.1f%%" , title = "Sex Category")
# Out:
# <AxesSubplot:title={'center':'Sex Category'}, ylabel='Sex'>

# %%
df.head(3)
# Out:
#    Age         Work-Class  Final Weight   Education  Education-Num  \
# 0   39          State gov         77516   Bachelors             13
# 1   50   Self emp not inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
#
#         Marital Status          Occupation    Relationship    Race    Sex  \
# 0        Never Married        Adm clerical   Not in family   White   Male
# 1   Married civ SpouSe     Exec managerial         Husband   White   Male
# 2             Divorced   Handlers cleaners   Not in family   White   Male
#
#    Capital Gain  Capital Loss  Hour-Per-Week  Netive Country
# 0          2174             0             40   United States
# 1             0             0             13   United States
# 2             0             0             40   United States

# %%
df5 = df["Marital Status"].value_counts().reset_index()

# %%
df5 = df5.rename(columns = {"index" : "Marital Status" , "Marital Status" : "Total Number"})

# %%
df5
# Out:
#            Marital Status  Total Number
# 0      Married civ SpouSe         14976
# 1           Never Married         10683
# 2                Divorced          4443
# 3               Separated          1025
# 4                 Widowed           993
# 5   Married SpouSe abSent           418
# 6       Married AF SpouSe            23

# %%
plt.figure(figsize = (15,15))
plt.title("Number Of Marital Status" , fontsize = 15 , fontweight = "bold" , alpha =0.8 , y =1)
sns.barplot(x = "Marital Status" , y = "Total Number" , data=df5)
plt.xticks(rotation = 45 )
plt.show()
